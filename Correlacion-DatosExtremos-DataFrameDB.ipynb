# %% [markdown]
# # Correlacion entre datos

# %%
import numpy as np
from sklearn.datasets import load_boston
import pandas as pd

# %%
boston = load_boston()
df = pd.DataFrame(boston.data)

# %%
df.columns = boston.feature_names
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
# correlacion entre dos columnas, tener en cuenta que si hay un valor Na
# retornara na, primero se debe limpiar estos valores
np.corrcoef(df['ZN'],df['INDUS'])
# Out:
# array([[ 1.        , -0.53382819],
#        [-0.53382819,  1.        ]])

# %%
# matriz de correlaciones
corr = round(df.corr(),3)
# le ponemos un degrade para visualizar mas facil
corr.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row0_col1 {
#             background-color:  #d3d4e7;
#             color:  #000000;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row0_col2 {
#             background-color:  #2a88bc;
#             color:  #000000;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row0_col3 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row0_col4 {
#             background-color:  #2383ba;
#             color:  #000000;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row0_col5 {
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row0_col6 {
#             background-color:  #348ebf;
#             color:  #000000;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row0_col7 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row0_col8 {
#             background-color:  #0570b0;
#             color:  #f1f1f1;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row0_col9 {
#             background-color:  #0d75b3;
#             color:  #f1f1f1;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row0_col10 {
#             background-color:  #78abd0;
#             color:  #000000;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row0_col11 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row0_col12 {
#             background-color:  #2786bb;
#             color:  #000000;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row1_col0 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row1_col2 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row1_col3 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row1_col4 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row1_col5 {
#             background-color:  #509ac6;
#             color:  #000000;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row1_col6 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row1_col7 {
#             background-color:  #05659f;
#             color:  #f1f1f1;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row1_col8 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row1_col9 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row1_col10 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row1_col11 {
#             background-color:  #91b5d6;
#             color:  #000000;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row1_col12 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row2_col0 {
#             background-color:  #509ac6;
#             color:  #000000;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row2_col1 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row2_col3 {
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row2_col4 {
#             background-color:  #045b8f;
#             color:  #f1f1f1;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row2_col5 {
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row2_col6 {
#             background-color:  #0567a2;
#             color:  #f1f1f1;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row2_col7 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row2_col8 {
#             background-color:  #0d75b3;
#             color:  #f1f1f1;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row2_col9 {
#             background-color:  #04649d;
#             color:  #f1f1f1;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row2_col10 {
#             background-color:  #589ec8;
#             color:  #000000;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row2_col11 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row2_col12 {
#             background-color:  #056fae;
#             color:  #f1f1f1;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row3_col0 {
#             background-color:  #d3d4e7;
#             color:  #000000;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row3_col1 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row3_col2 {
#             background-color:  #88b1d4;
#             color:  #000000;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row3_col4 {
#             background-color:  #79abd0;
#             color:  #000000;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row3_col5 {
#             background-color:  #8eb3d5;
#             color:  #000000;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row3_col6 {
#             background-color:  #7dacd1;
#             color:  #000000;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row3_col7 {
#             background-color:  #a5bddb;
#             color:  #000000;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row3_col8 {
#             background-color:  #b7c5df;
#             color:  #000000;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row3_col9 {
#             background-color:  #b7c5df;
#             color:  #000000;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row3_col10 {
#             background-color:  #dddbec;
#             color:  #000000;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row3_col11 {
#             background-color:  #b1c2de;
#             color:  #000000;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row3_col12 {
#             background-color:  #b0c2de;
#             color:  #000000;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row4_col0 {
#             background-color:  #4c99c5;
#             color:  #000000;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row4_col1 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row4_col2 {
#             background-color:  #045c90;
#             color:  #f1f1f1;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row4_col3 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row4_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row4_col5 {
#             background-color:  #dddbec;
#             color:  #000000;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row4_col6 {
#             background-color:  #045f95;
#             color:  #f1f1f1;
#         }    #T_fc77e1da_c1ee_11e9_b11d_2c6fc92570e6row4_col7 {
#             background-color:  #fff7fb;
#             color:

# %% [markdown]
# # Análisis de datos extremos

# %%
X = df['AGE'].dropna()

# %%
X.describe()
# Out:
# count    506.000000
# mean      68.574901
# std       28.148861
# min        2.900000
# 25%       45.025000
# 50%       77.500000
# 75%       94.075000
# max      100.000000
# Name: AGE, dtype: float64

# %%
q1 = np.percentile(X,25)
q3 = np.percentile(X,75)
rango = q3 - q1

# %%
umbralSup = q1 + 1.5*rango
umbralInf = q3 - 1.5*rango

# %%
umbralInf
# Out:
# 20.5

# %%
umbralSup
# Out:
# 118.6

# %%
# porcentaje de muestras fuera del umbral superior
np.mean(X > umbralSup)
# Out:
# 0.0

# %%
# porcentaje de muestras fuera del umbral inferior
np.mean(X < umbralInf)
# Out:
# 0.0691699604743083

# %%
from sklearn.covariance import EllipticEnvelope

# %%
# modelo para encontrar los valores fuera del rango (outliers)
outliers = EllipticEnvelope(contamination = .01)

# %%
var_list = ['AGE','DIS']
x = np.array(df[var_list].dropna())

# %%
outliers.fit(x)
# Out:
# EllipticEnvelope(assume_centered=False, contamination=0.01, random_state=None,
#                  store_precision=True, support_fraction=None)

# %%
pred = outliers.predict(x)

# %%
np.where(pred==-1)[0]
# Out:
# array([ 64, 351, 352, 353, 354, 355], dtype=int64)

# %% [markdown]
# # Transformacopn de data frame a base de datos relacional

# %%
data = [(1,"Pepe","Grillo", 25, 1, "Libreta", 1.2,.4,.8,3,"03-12-2018"),
        (1,"Pepe","Grillo", 25, 2, "Goma", .4,.15,.25,1,"12-2-2018"),
        (1,"Pepe","Grillo", 25, 1, "Libreta", 1.2,.4,.8,2,"03-12-2018"),
        (2,"Juan","Casanova", 33, 2, "Goma", .4,.15,.25,1,"12-2-2018"),
        (2,"Juan","Casanova", 25, 1, "Libreta", 1.2,.4,.8,3,"03-12-2018"),
        (3,"Luis Alberto","Spinetta", 43, 1, "Libreta", 1.2,.4,.8,1,"03-06-2018"),
        (3,"Luis Alberto","Spinetta", 43, 1, "Libreta", 1.2,.4,.8,3,"03-08-2018")] 
labels = ["cli_id", "cli_nombre", "cli_apellido", "cli_edad", "pro_id",
          "pro_name","precio","coste","margen","cantidad","fecha"]

# %%
df = pd.DataFrame.from_records(data, columns = labels)
df
# Out:
#    cli_id    cli_nombre cli_apellido  cli_edad  pro_id pro_name  precio  \
# 0       1          Pepe       Grillo        25       1  Libreta     1.2
# 1       1          Pepe       Grillo        25       2     Goma     0.4
# 2       1          Pepe       Grillo        25       1  Libreta     1.2
# 3       2          Juan     Casanova        33       2     Goma     0.4
# 4       2          Juan     Casanova        25       1  Libreta     1.2
# 5       3  Luis Alberto     Spinetta        43       1  Libreta     1.2
# 6       3  Luis Alberto     Spinetta        43       1  Libreta     1.2
#
#    coste  margen  cantidad       fecha
# 0   0.40    0.80         3  03-12-2018
# 1   0.15    0.25         1   12-2-2018
# 2   0.40    0.80         2  03-12-2018
# 3   0.15    0.25         1   12-2-2018
# 4   0.40    0.80         3  03-12-2018
# 5   0.40    0.80         1  03-06-2018
# 6   0.40    0.80         3  03-08-2018

# %%
clientes = df.drop_duplicates(subset = 'cli_id', keep="first")
clientes
# Out:
#    cli_id    cli_nombre cli_apellido  cli_edad  pro_id pro_name  precio  \
# 0       1          Pepe       Grillo        25       1  Libreta     1.2
# 3       2          Juan     Casanova        33       2     Goma     0.4
# 5       3  Luis Alberto     Spinetta        43       1  Libreta     1.2
#
#    coste  margen  cantidad       fecha
# 0   0.40    0.80         3  03-12-2018
# 3   0.15    0.25         1   12-2-2018
# 5   0.40    0.80         1  03-06-2018

# %%
clientes = compradores[['cli_id','cli_nombre','cli_apellido','cli_edad']]
clientes
# Out:
#    cli_id    cli_nombre cli_apellido  cli_edad
# 0       1          Pepe       Grillo        25
# 3       2          Juan     Casanova        33
# 5       3  Luis Alberto     Spinetta        43

# %%
productos = df.drop_duplicates(subset= 'pro_id', keep='first')

# %%
productos = df[['pro_id','pro_name','precio','coste','margen']]
productos
# Out:
#    pro_id pro_name  precio  coste  margen
# 0       1  Libreta     1.2   0.40    0.80
# 1       2     Goma     0.4   0.15    0.25
# 2       1  Libreta     1.2   0.40    0.80
# 3       2     Goma     0.4   0.15    0.25
# 4       1  Libreta     1.2   0.40    0.80
# 5       1  Libreta     1.2   0.40    0.80
# 6       1  Libreta     1.2   0.40    0.80

# %%
compras = df[['cli_id','pro_id','fecha','cantidad']]
compras
# Out:
#    cli_id  pro_id       fecha  cantidad
# 0       1       1  03-12-2018         3
# 1       1       2   12-2-2018         1
# 2       1       1  03-12-2018         2
# 3       2       2   12-2-2018         1
# 4       2       1  03-12-2018         3
# 5       3       1  03-06-2018         1
# 6       3       1  03-08-2018         3
