# %% [markdown]
# # Análisis de datos para caso Titanic

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('train.csv')
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# el PassengerId y el nombre del pasajero es poco relevante para el análisis así que los removemos
data.drop(columns=['PassengerId','Name'],inplace=True)

# %%
data.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0         0       3    male  22.0      1      0         A/5 21171   7.2500
# 1         1       1  female  38.0      1      0          PC 17599  71.2833
# 2         1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3         1       1  female  35.0      1      0            113803  53.1000
# 4         0       3    male  35.0      0      0            373450   8.0500
#
#   Cabin Embarked
# 0   NaN        S
# 1   C85        C
# 2   NaN        S
# 3  C123        S
# 4   NaN        S

# %% [markdown]
# #  Convertimos datos categóricos a cuantitativos

# %%
labels = 'Male','Female'
sizes = data.Sex.value_counts()
plt.pie(sizes, labels=labels, explode= (0, 0.1), shadow=True, startangle=90, autopct='%1.1f%%')
plt.title('Porcentaje de hombres y mujeres en el barco')
plt.show()

# %%
# no podemos trabajar con variables categoricas como el sexo, 
# por lo tanto realizamos conversion. male:1 y female:0

data = data.replace({"male": 1, "female":0})
data.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0         0       3    1  22.0      1      0         A/5 21171   7.2500   NaN
# 1         1       1    0  38.0      1      0          PC 17599  71.2833   C85
# 2         1       3    0  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 3         1       1    0  35.0      1      0            113803  53.1000  C123
# 4         0       3    1  35.0      0      0            373450   8.0500   NaN
#
#   Embarked
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S

# %%
# Cantidad de pasajeros por clase

clases = ["Clase 3","Clase 1","Clase 2"]
sizes = data.Pclass.value_counts()

plt.bar(clases, sizes, color = ["Red",'Yellow',"Green"])
plt.title("Cantidad de pasajeros por clase")
# Out:
# Text(0.5, 1.0, 'Cantidad de pasajeros por clase')

# %% [markdown]
# # Hay que verificar si tenemos datos faltantes y definir el qué hacer con ellos

# %%
data.Age.isnull().value_counts()
# Out:
# False    714
# True     177
# Name: Age, dtype: int64

# %% [markdown]
# Obervamos que tenemos 177 casos donde la edad no está cargada. Hay que definir cómo tratarlos, hay varias alternativas:
#     * eliminar tales registros
#     * remplazar estos valores con algún otro (media, moda, mediana, etc.)
# Se reemplazara  los valores por la media en este caso

# %%
round(data.Age.mean())
# Out:
# 30

# %%
# reemplazo los valores null con la media redondeada
data['Age'].fillna(round(data.Age.mean()), inplace=True)

# %%
data.Age.isnull().value_counts()
# Out:
# False    891
# Name: Age, dtype: int64

# %% [markdown]
# observamos que ahora ya no tenemos valores null en la columna Age =D
#
# ---------------------
#
# # Expandir dimensión del vector
#
# Columna SibSp representa la cantidad de hermanos en el titanic de la persona.
#
# Columna Parch la cantidad de hijos/padres en el barco
#
# Podriamos crear nueva dimensión "Family" a partir de la sumatoria de las columnas previamente mencionadas

# %%
#acumulamos todo en Parch
data['Parch'] = data['SibSp'] + data ['Parch']

# dropeamos columna SibSp
data.drop(columns='SibSp',inplace=True)

# renombramos el nombre de la columna
data.rename(columns={"Parch":"Family"}, inplace=True)

# %%
data.head()
# Out:
#    Survived  Pclass  Sex   Age  Family            Ticket     Fare Cabin  \
# 0         0       3    1  22.0       1         A/5 21171   7.2500   NaN
# 1         1       1    0  38.0       1          PC 17599  71.2833   C85
# 2         1       3    0  26.0       0  STON/O2. 3101282   7.9250   NaN
# 3         1       1    0  35.0       1            113803  53.1000  C123
# 4         0       3    1  35.0       0            373450   8.0500   NaN
#
#   Embarked
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S

# %%
# la columna ticket no nos brinda información útil para la predicción 
# por lo tanto podemos eliminarla para nuestro análisis

data.drop(columns='Ticket',inplace=True)

# %%
data.head()
# Out:
#    Survived  Pclass  Sex   Age  Family     Fare Cabin Embarked
# 0         0       3    1  22.0       1   7.2500   NaN        S
# 1         1       1    0  38.0       1  71.2833   C85        C
# 2         1       3    0  26.0       0   7.9250   NaN        S
# 3         1       1    0  35.0       1  53.1000  C123        S
# 4         0       3    1  35.0       0   8.0500   NaN        S

# %% [markdown]
# # Datos faltante en column Cabin
# * en este caso hay muchos datos faltantes pero no podemos reemplazar los datos faltantes a partir de los otros datos(no se puede aplicar media,mediana y la moda no tiene sentido aplicarlo en este caso), por lo tanto debemos de eliminar los registros con datos faltantes

# %%
data.Cabin.isnull().value_counts()
# Out:
# True     687
# False    204
# Name: Cabin, dtype: int64

# %%
data.drop(columns='Cabin',inplace=True)

# %%
data.head()
# Out:
#    Survived  Pclass  Sex   Age  Family     Fare Embarked
# 0         0       3    1  22.0       1   7.2500        S
# 1         1       1    0  38.0       1  71.2833        C
# 2         1       3    0  26.0       0   7.9250        S
# 3         1       1    0  35.0       1  53.1000        S
# 4         0       3    1  35.0       0   8.0500        S

# %%
# Embarked nos da en que puerto arrivaron al bote
# intentamos observar si tiene relación con si las personas sobrevivieron por ello o no

data.groupby('Embarked')['Survived'].value_counts()
# Out:
# Embarked  Survived
# C         1            93
#           0            75
# Q         0            47
#           1            30
# S         0           427
#           1           217
# Name: Survived, dtype: int64

# %% [markdown]
#  * Aparentemente no hay relación alguna por lo tanto podemos eliminar tal columna

# %%
data.drop(columns='Embarked',inplace=True)

# %%
data.head()
# Out:
#    Survived  Pclass  Sex   Age  Family     Fare
# 0         0       3    1  22.0       1   7.2500
# 1         1       1    0  38.0       1  71.2833
# 2         1       3    0  26.0       0   7.9250
# 3         1       1    0  35.0       1  53.1000
# 4         0       3    1  35.0       0   8.0500

# %% [markdown]
# # Análisis de correlación

# %%
corr = round(data.corr(),3)
corr.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row0_col1 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row0_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row0_col3 {
#             background-color:  #dddbec;
#             color:  #000000;
#         }    #T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row0_col4 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row0_col5 {
#             background-color:  #69a5cc;
#             color:  #000000;
#         }    #T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row1_col0 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row1_col2 {
#             background-color:  #8eb3d5;
#             color:  #000000;
#         }    #T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row1_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row1_col4 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row1_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row2_col1 {
#             background-color:  #8cb3d5;
#             color:  #000000;
#         }    #T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row2_col3 {
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }    #T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row2_col4 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row2_col5 {
#             background-color:  #d3d4e7;
#             color:  #000000;
#         }    #T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row3_col0 {
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }    #T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row3_col1 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row3_col2 {
#             background-color:  #99b8d8;
#             color:  #000000;
#         }    #T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row3_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row3_col5 {
#             background-color:  #97b7d7;
#             color:  #000000;
#         }    #T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row4_col0 {
#             background-color:  #abbfdc;
#             color:  #000000;
#         }    #T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row4_col1 {
#             background-color:  #9ebad9;
#             color:  #000000;
#         }    #T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row4_col2 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row4_col3 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row4_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row4_col5 {
#             background-color:  #76aad0;
#             color:  #000000;
#         }    #T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row5_col0 {
#             background-color:  #6ba5cd;
#             color:  #000000;
#         }    #T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row5_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row5_col2 {
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }    #T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row5_col3 {
#             background-color:  #b9c6e0;
#             color:  #000000;
#         }    #T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row5_col4 {
#             background-color:  #a7bddb;
#             color:  #000000;
#         }    #T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row5_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }</style><table id="T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Survived</th>        <th class="col_heading level0 col1" >Pclass</th>        <th class="col_heading level0 col2" >Sex</th>        <th class="col_heading level0 col3" >Age</th>        <th class="col_heading level0 col4" >Family</th>        <th class="col_heading level0 col5" >Fare</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6level0_row0" class="row_heading level0 row0" >Survived</th>
#                         <td id="T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row0_col1" class="data row0 col1" >-0.338</td>
#                         <td id="T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row0_col2" class="data row0 col2" >-0.543</td>
#                         <td id="T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row0_col3" class="data row0 col3" >-0.071</td>
#                         <td id="T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row0_col4" class="data row0 col4" >0.017</td>
#                         <td id="T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row0_col5" class="data row0 col5" >0.257</td>
#             </tr>
#             <tr>
#                         <th id="T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6level0_row1" class="row_heading level0 row1" >Pclass</th>
#                         <td id="T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row1_col0" class="data row1 col0" >-0.338</td>
#                         <td id="T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row1_col1" class="data row1 col1" >1</td>
#                         <td id="T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row1_col2" class="data row1 col2" >0.132</td>
#                         <td id="T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row1_col3" class="data row1 col3" >-0.33</td>
#                         <td id="T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row1_col4" class="data row1 col4" >0.066</td>
#                         <td id="T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row1_col5" class="data row1 col5" >-0.549</td>
#             </tr>
#             <tr>
#                         <th id="T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6level0_row2" class="row_heading level0 row2" >Sex</th>
#                         <td id="T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row2_col0" class="data row2 col0" >-0.543</td>
#                         <td id="T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row2_col1" class="data row2 col1" >0.132</td>
#                         <td id="T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row2_col2" class="data row2 col2" >1</td>
#                         <td id="T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row2_col3" class="data row2 col3" >0.085</td>
#                         <td id="T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row2_col4" class="data row2 col4" >-0.201</td>
#                         <td id="T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6row2_col5" class="data row2 col5" >-0.182</td>
#             </tr>
#             <tr>
#                         <th id="T_30e4dfc8_c2e2_11e9_881d_2c6fc92570e6level0_row3" class="row_heading level0 row3" >Age</th>

# %% [markdown]
# ## Observamos de esto que:
#    ### * Sobrevivir está muy correlacionado con el sexo de la persona, la clase por la que se pago, y a menor medida con el precio del ticket
#    ### * La clase con el precio del ticket está muy correlacionada

# %% [markdown]
# # Modelo MultiLayerPerceptron

# %%
from sklearn.neural_network import MLPClassifier

X = data.drop(columns="Survived")
Y = data.Survived

mlp = MLPClassifier(alpha=1e-4, hidden_layer_sizes=(5,2), random_state=1
                   ,max_iter = 2000)

mlp.fit(X,Y)
# Out:
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(5, 2), learning_rate='constant',
#               learning_rate_init=0.001, max_iter=2000, momentum=0.9,
#               n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#               random_state=1, shuffle=True, solver='adam', tol=0.0001,
#               validation_fraction=0.1, verbose=False, warm_start=False)

# %%
data_test = pd.read_csv("test.csv")

data_test.drop(columns=['Cabin','Name', 'Embarked','Ticket','PassengerId'], inplace= True)

# %%
data_test['SibSp'] = data_test['SibSp']+data_test['Parch']

# %%
data_test.rename(columns={"SibSp":"Family"}, inplace=True)

# %%
data_test.drop(columns="Parch",inplace=True)

# %%
data_test.Age.fillna(round(data_test.Age.mean()), inplace=True)

# %%
data_test.replace({"male":1, "female":0}, inplace=True)

# %%
data_test.Fare.fillna(data_test.Fare.mean(), inplace=True)

# %%
from sklearn.metrics import mean_squared_error

## hacemos la predicicon con nuestros datos de de entrenamiento

predict = mlp.predict(X)

mean_squared_error(Y, predict)
# Out:
# 0.20202020202020202

# %%
# ahora sobre el data_test

result_real = pd.read_csv("gender_submission.csv")

predict_test = mlp.predict(data_test)

mean_squared_error(result_real['Survived'], predict_test)

results = pd.DataFrame(result_real['Survived'], columns=["Real"])

# %%
#result_real['Survived'].values
results['Real'] = result_real['Survived']

# %%
results['Predict'] = predict_test

# %%
result_real['Predict'] = predict_test

# %%
result_real
# Out:
#      PassengerId  Survived  Predict
# 0            892         0        0
# 1            893         1        1
# 2            894         0        0
# 3            895         0        0
# 4            896         1        1
# 5            897         0        0
# 6            898         1        1
# 7            899         0        0
# 8            900         1        1
# 9            901         0        0
# 10           902         0        0
# 11           903         0        0
# 12           904         1        1
# 13           905         0        0
# 14           906         1        1
# 15           907         1        1
# 16           908         0        0
# 17           909         0        0
# 18           910         1        1
# 19           911         1        1
# 20           912         0        0
# 21           913         0        0
# 22           914         1        1
# 23           915         0        0
# 24           916         1        1
# 25           917         0        0
# 26           918         1        1
# 27           919         0        0
# 28           920         0        0
# 29           921         0        0
# ..           ...       ...      ...
# 388         1280         0        0
# 389         1281         0        0
# 390         1282         0        1
# 391         1283         1        1
# 392         1284         0        0
# 393         1285         0        0
# 394         1286         0        0
# 395         1287         1        1
# 396         1288         0        0
# 397         1289         1        1
# 398         1290         0        0
# 399         1291         0        0
# 400         1292         1        1
# 401         1293         0        0
# 402         1294         1        1
# 403         1295         0        0
# 404         1296         0        0
# 405         1297         0        0
# 406         1298         0        0
# 407         1299         0        1
# 408         1300         1        1
# 409         1301         1        1
# 410         1302         1        1
# 411         1303         1        1
# 412         1304         1        1
# 413         1305         0        0
# 414         1306         1        1
# 415         1307         0        0
# 416         1308         0        0
# 417         1309         0        0
#
# [418 rows x 3 columns]
